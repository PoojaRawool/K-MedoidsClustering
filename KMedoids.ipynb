# %%
conda install -c conda-forge scikit-learn-extra
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\Anaconda
#
#
# Note: you may need to restart the kernel to use updated packages.  added / updated specs:
#     - scikit-learn-extra
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#
#     ---------------------------|-----------------
#     conda-4.9.2                |   py38haa244fe_0         3.1 MB  conda-forge
#     python_abi-3.8             |           1_cp38           4 KB  conda-forge
#     scikit-learn-extra-0.1.0b2 |   py38h4b8e87e_0         127 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/win-64::python_abi-3.8-1_cp38
#   scikit-learn-extra conda-forge/win-64::scikit-learn-extra-0.1.0b2-py38h4b8e87e_0
#
# ...

# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns
from sklearn_extra.cluster import KMedoids
# %matplotlib notebook

# %%
# %cd D:\MSC\Trimester3\ML2\Datasets
# Out:
# D:\MSC\Trimester3\ML2\Datasets

# %%
dataset=pd.read_csv("CarbonEmissionIndia.csv")

# %%
dataset.head()
# Out:
#            States  per capita CO2 (kg per person)  \
# 0  Andhra Pradesh                          974.17
# 1       Arunachal                          405.90
# 2           Assam                          340.91
# 3           Bihar                          179.01
# 4     Chattisgarh                         1963.88
#
#    per capita CO (kg per person)  per capita CH4 (kg per person)
# 0                          27.18                           16.97
# 1                          17.43                           25.82
# 2                          16.63                           21.29
# 3                           8.83                            9.59
# 4                          17.56                           22.37

# %%
x=dataset.values[:,1:dataet.shape[1]]
Kmeds=KMedoids(n_clusters=3,random_state=0).fit(x)

# %%
Kmeds.labels_
# Out:
# array([0, 2, 2, 2, 1, 1, 1, 1, 0, 2, 1, 0, 0, 0, 0, 2, 0, 0, 1, 0, 1, 0,
#        0, 0, 2, 2, 2, 0], dtype=int64)

# %%
Kmeds.predict(x)
# Out:
# array([0, 2, 2, 2, 1, 1, 1, 1, 0, 2, 1, 0, 0, 0, 0, 2, 0, 0, 1, 0, 1, 0,
#        0, 0, 2, 2, 2, 0], dtype=int64)

# %%
Kmeds.cluster_centers_
# Out:
# array([[ 784.16,   16.98,   18.28],
#        [1403.43,   15.02,   15.39],
#        [ 379.2 ,   10.8 ,   22.63]])

# %%
Kmeds.inertia_
# Out:
# 4008.4869759435473

# %%
Kmeds.medoid_indices_
# Out:
# array([ 8, 10, 15], dtype=int64)

# %%
x[8]
# Out:
# array([784.16, 16.98, 18.28], dtype=object)

# %%
x[10]
# Out:
# array([1403.43, 15.02, 15.39], dtype=object)

# %%
x[15]
# Out:
# array([379.2, 10.8, 22.63], dtype=object)

# %%
dataset.columns
# Out:
# Index(['States', 'per capita CO2 (kg per person)',
#        'per capita CO (kg per person)', 'per capita CH4 (kg per person)'],
#       dtype='object')

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax=plt.axes(projection='3d')
x=dataset["per capita CO2 (kg per person)"]
y=dataset["per capita CO (kg per person)"]
z=dataset["per capita CH4 (kg per person)"]
ax.scatter3D(x,y,z,c=Kmeds.labels_,cmap="plasma")
ax.scatter3D(Kmeds.cluster_centers_[:,0],Kmeds.cluster_centers_[:,1],Kmeds.cluster_centers_[:,2],c="black",s=35,alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dataset=pd.read_csv("Sample_Cluster_Data.csv")

# %%
dataset.head()
# Out:
#         X       Y
# 0  664159  550946
# 1  665845  557965
# 2  597173  575538
# 3  618600  551446
# 4  635690  608046

# %%
x=dataset.values
Kmeds=KMedoids(n_clusters=3,random_state=0).fit(x)

# %%
Kmeds.labels_
# Out:
# array([2, 2, 2, ..., 1, 1, 1], dtype=int64)

# %%
Kmeds.predict(x)
# Out:
# array([2, 2, 2, ..., 1, 1, 1], dtype=int64)

# %%
Kmeds.cluster_centers_
# Out:
# array([[269126, 508814],
#        [671609, 815681],
#        [686324, 364237]], dtype=int64)

# %%
Kmeds.inertia_
# Out:
# 991418897.3155099

# %%
Kmeds.medoid_indices_
# Out:
# array([1827, 4821, 2300], dtype=int64)

# %%
fig=plt.figure()
x=dataset["X"]
y=dataset["Y"]
plt.scatter(x,y,c=Kmeds.labels_,cmap="plasma")
plt.scatter(Kmeds.cluster_centers_[:,0],Kmeds.cluster_centers_[:,1],c="black",s=35,alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="640">
